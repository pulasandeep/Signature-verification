# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread("sand1.png")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (72, 161, 3)

# %%
plt.imshow(image)

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')

# %%
WIDTH = 30
HEIGHT = 30

# %%
resized = cv2.resize(gray,(WIDTH,HEIGHT))

plt.imshow(resized)

# %%
aspect = image.shape[1] / float(image.shape[0])
print(aspect)

if(aspect > 1):
    res= int(aspect * HEIGHT)
    scaled = cv2.resize(image,(res, HEIGHT))
    
if(aspect < 1):
    res= int(WIDTH / aspect)
    scaled = cv2.resize(image,(WIDTH, res))
    
if(aspect == 1):
    scaled = cv2.resize(image,(WIDTH, HEIGHT))
    
plt.imshow(scaled)
# Out:
# 2.236111111111111

# %%
def crop_center(img, cropx, cropy):
    y,x,c = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)
    return img[starty:starty+cropy, startx:startx+cropx]


cropped = crop_center(scaled, WIDTH, WIDTH)

plt.imshow(cropped, cmap='gray')

# %%
from sklearn.externals import joblib
import numpy as np
import csv
import glob

# %%
label='sand1'
roi = cv2.resize(gray, (30, 30 ), interpolation=cv2.INTER_AREA)
plt.imshow(roi)

# %%
pixel=roi[15,15]
print(pixel)
# Out:
# 166

# %%
data=[]
data.append(label)
rows=30
cols=30
    
for i in range(rows):
    for j in range(cols):
        k = roi[i,j]
        if 155<k<170:
            k=1
        else:
            k=0
        

        data.append(k)
            
    with open('data.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    
cv2.waitKey()
# Out:
# -1
